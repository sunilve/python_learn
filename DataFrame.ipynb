# %%
import os

# %%
import pandas as pd

# %%
imp1=pd.read_csv('C:\\Users\\Sunil\\Desktop\\R_data\\Demographic.csv')

# %%
imp1
# Out:
#              Country Name Country Code  Birth rate  Internet users  \
# 0                   Aruba          ABW      10.244            78.9
# 1             Afghanistan          AFG      35.253             5.9
# 2                  Angola          AGO      45.985            19.1
# 3                 Albania          ALB      12.877            57.2
# 4    United Arab Emirates          ARE      11.044            88.0
# ..                    ...          ...         ...             ...
# 190           Yemen, Rep.          YEM      32.947            20.0
# 191          South Africa          ZAF      20.850            46.5
# 192      Congo, Dem. Rep.          COD      42.394             2.2
# 193                Zambia          ZMB      40.471            15.4
# 194              Zimbabwe          ZWE      35.715            18.5
#
#             Income Group
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ...

# %%
print(os.getcwd())
# Out:
# C:\Users\Sunil\Desktop\Py_learn\Python Learn

# %%
os.chdir('C:\\Users\\Sunil\\Desktop\\R_data')

# %%
imp2=pd.read_csv('Demographic.csv')

# %%
imp2
# Out:
#              Country Name Country Code  Birth rate  Internet users  \
# 0                   Aruba          ABW      10.244            78.9
# 1             Afghanistan          AFG      35.253             5.9
# 2                  Angola          AGO      45.985            19.1
# 3                 Albania          ALB      12.877            57.2
# 4    United Arab Emirates          ARE      11.044            88.0
# ..                    ...          ...         ...             ...
# 190           Yemen, Rep.          YEM      32.947            20.0
# 191          South Africa          ZAF      20.850            46.5
# 192      Congo, Dem. Rep.          COD      42.394             2.2
# 193                Zambia          ZMB      40.471            15.4
# 194              Zimbabwe          ZWE      35.715            18.5
#
#             Income Group
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ...

# %%
os.chdir('C:\\Users\\Sunil\\Desktop\\Py_learn\\Python Learn')

# %%
len(imp1)
# Out:
# 195

# %%
imp1.columns
# Out:
# Index(['Country Name', 'Country Code', 'Birth rate', 'Internet users',
#        'Income Group'],
#       dtype='object')

# %%
imp1.describe()
# Out:
#        Birth rate  Internet users
# count  195.000000      195.000000
# mean    21.469928       42.076471
# std     10.605467       29.030788
# min      7.900000        0.900000
# 25%     12.120500       14.520000
# 50%     19.680000       41.000000
# 75%     29.759500       66.225000
# max     49.661000       96.546800

# %%
imp1.head()
# Out:
#            Country Name Country Code  Birth rate  Internet users  \
# 0                 Aruba          ABW      10.244            78.9
# 1           Afghanistan          AFG      35.253             5.9
# 2                Angola          AGO      45.985            19.1
# 3               Albania          ALB      12.877            57.2
# 4  United Arab Emirates          ARE      11.044            88.0
#
#           Income Group
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
imp1.tail()
# Out:
#          Country Name Country Code  Birth rate  Internet users  \
# 190       Yemen, Rep.          YEM      32.947            20.0
# 191      South Africa          ZAF      20.850            46.5
# 192  Congo, Dem. Rep.          COD      42.394             2.2
# 193            Zambia          ZMB      40.471            15.4
# 194          Zimbabwe          ZWE      35.715            18.5
#
#             Income Group
# 190  Lower middle income
# 191  Upper middle income
# 192           Low income
# 193  Lower middle income
# 194           Low income

# %%
imp1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country Name    195 non-null    object
#  1   Country Code    195 non-null    object
#  2   Birth rate      195 non-null    float64
#  3   Internet users  195 non-null    float64
#  4   Income Group    195 non-null    object
# dtypes: float64(2), object(3)
# memory usage: 5.4+ KB

# %%
imp1.columns
# Out:
# Index(['Country Name', 'Country Code', 'Birth rate', 'Internet users',
#        'Income Group'],
#       dtype='object')

# %%
imp1.columns=['CountryName','CountryCode','BirthRate','InternetUsers','IncomeGroup']

# %%
imp1.head(10)
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244        78.9000
# 1           Afghanistan         AFG     35.253         5.9000
# 2                Angola         AGO     45.985        19.1000
# 3               Albania         ALB     12.877        57.2000
# 4  United Arab Emirates         ARE     11.044        88.0000
# 5             Argentina         ARG     17.716        59.9000
# 6               Armenia         ARM     13.308        41.9000
# 7   Antigua and Barbuda         ATG     16.447        63.4000
# 8             Australia         AUS     13.200        83.0000
# 9               Austria         AUT      9.400        80.6188
#
#            IncomeGroup
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income
# 5          High income
# 6  Lower middle income
# 7          High income
# 8          High income
# 9          High income

# %%
imp1[:5]
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
imp1[-8:-5]
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 187             Vanuatu         VUT     26.739           11.3
# 188  West Bank and Gaza         PSE     30.394           46.6
# 189               Samoa         WSM     26.172           15.3
#
#              IncomeGroup
# 187  Lower middle income
# 188  Lower middle income
# 189  Lower middle income

# %%
i=1
while i<=195:
    print ( imp1[-i:])
    i=i+1
# Out:
#     CountryName CountryCode  BirthRate  InternetUsers IncomeGroup
# 194    Zimbabwe         ZWE     35.715           18.5  Low income
#     CountryName CountryCode  BirthRate  InternetUsers          IncomeGroup
# 193      Zambia         ZMB     40.471           15.4  Lower middle income
# 194    Zimbabwe         ZWE     35.715           18.5           Low income
#           CountryName CountryCode  BirthRate  InternetUsers  \
# 192  Congo, Dem. Rep.         COD     42.394            2.2
# 193            Zambia         ZMB     40.471           15.4
# 194          Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 192           Low income
# 193  Lower middle income
# 194           Low income
#           CountryName CountryCode  BirthRate  InternetUsers  \
# 191      South Africa         ZAF     20.850           46.5
# 192  Congo, Dem. Rep.         COD     42.394            2.2
# 193            Zambia         ZMB     40.471           15.4
# ...

# %%
imp1[::-1]
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 194              Zimbabwe         ZWE     35.715           18.5
# 193                Zambia         ZMB     40.471           15.4
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 191          South Africa         ZAF     20.850           46.5
# 190           Yemen, Rep.         YEM     32.947           20.0
# ..                    ...         ...        ...            ...
# 4    United Arab Emirates         ARE     11.044           88.0
# 3                 Albania         ALB     12.877           57.2
# 2                  Angola         AGO     45.985           19.1
# 1             Afghanistan         AFG     35.253            5.9
# 0                   Aruba         ABW     10.244           78.9
#
#              IncomeGroup
# 194           Low income
# 193  Lower middle income
# 192           Low income
# 191  Upper middle income
# 190  Lower middle income
# ..                   ...
# ...

# %%
imp1[::20]
# Out:
#     CountryName CountryCode  BirthRate  InternetUsers          IncomeGroup
# 0         Aruba         ABW     10.244        78.9000          High income
# 20      Belarus         BLR     12.500        54.1700  Upper middle income
# 40   Costa Rica         CRI     15.022        45.9600  Upper middle income
# 60        Gabon         GAB     30.555         9.2000  Upper middle income
# 80        India         IND     20.291        15.1000  Lower middle income
# 100       Libya         LBY     21.425        16.5000  Upper middle income
# 120  Mozambique         MOZ     39.705         5.4000           Low income
# 140      Poland         POL      9.600        62.8492          High income
# 160    Suriname         SUR     18.455        37.4000  Upper middle income
# 180     Uruguay         URY     14.374        57.6900          High income

# %%
imp1[['CountryName']]
# Out:
#               CountryName
# 0                   Aruba
# 1             Afghanistan
# 2                  Angola
# 3                 Albania
# 4    United Arab Emirates
# ..                    ...
# 190           Yemen, Rep.
# 191          South Africa
# 192      Congo, Dem. Rep.
# 193                Zambia
# 194              Zimbabwe
#
# [195 rows x 1 columns]

# %%
imp1[3:9][["CountryName","IncomeGroup","BirthRate"]]
# Out:
#             CountryName          IncomeGroup  BirthRate
# 3               Albania  Upper middle income     12.877
# 4  United Arab Emirates          High income     11.044
# 5             Argentina          High income     17.716
# 6               Armenia  Lower middle income     13.308
# 7   Antigua and Barbuda          High income     16.447
# 8             Australia          High income     13.200

# %%
imp1[["CountryName","IncomeGroup","BirthRate"]][3:9]
# Out:
#             CountryName          IncomeGroup  BirthRate
# 3               Albania  Upper middle income     12.877
# 4  United Arab Emirates          High income     11.044
# 5             Argentina          High income     17.716
# 6               Armenia  Lower middle income     13.308
# 7   Antigua and Barbuda          High income     16.447
# 8             Australia          High income     13.200

# %%
result=imp1.BirthRate*imp1.InternetUsers

# %%
result.head()
# Out:
# 0    808.2516
# 1    207.9927
# 2    878.3135
# 3    736.5644
# 4    971.8720
# dtype: float64

# %%
imp1["MyCalc"]=result

# %%
imp1.drop('MyCalc',1)
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 0                   Aruba         ABW     10.244           78.9
# 1             Afghanistan         AFG     35.253            5.9
# 2                  Angola         AGO     45.985           19.1
# 3                 Albania         ALB     12.877           57.2
# 4    United Arab Emirates         ARE     11.044           88.0
# ..                    ...         ...        ...            ...
# 190           Yemen, Rep.         YEM     32.947           20.0
# 191          South Africa         ZAF     20.850           46.5
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 193                Zambia         ZMB     40.471           15.4
# 194              Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ..                   ...
# ...

# %%
imp1
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 0                   Aruba         ABW     10.244           78.9
# 1             Afghanistan         AFG     35.253            5.9
# 2                  Angola         AGO     45.985           19.1
# 3                 Albania         ALB     12.877           57.2
# 4    United Arab Emirates         ARE     11.044           88.0
# ..                    ...         ...        ...            ...
# 190           Yemen, Rep.         YEM     32.947           20.0
# 191          South Africa         ZAF     20.850           46.5
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 193                Zambia         ZMB     40.471           15.4
# 194              Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup    MyCalc
# 0            High income  808.2516
# 1             Low income  207.9927
# 2    Upper middle income  878.3135
# 3    Upper middle income  736.5644
# ...

# %%
imp1=imp1.drop('MyCalc',1)

# %%
imp1
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 0                   Aruba         ABW     10.244           78.9
# 1             Afghanistan         AFG     35.253            5.9
# 2                  Angola         AGO     45.985           19.1
# 3                 Albania         ALB     12.877           57.2
# 4    United Arab Emirates         ARE     11.044           88.0
# ..                    ...         ...        ...            ...
# 190           Yemen, Rep.         YEM     32.947           20.0
# 191          South Africa         ZAF     20.850           46.5
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 193                Zambia         ZMB     40.471           15.4
# 194              Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ..                   ...
# ...

# %%
Filter=(imp1.IncomeGroup=="Low income")

# %% [raw]
# Filter

# %%
imp1[Filter].head()
# Out:
#                  CountryName CountryCode  BirthRate  InternetUsers IncomeGroup
# 1                Afghanistan         AFG     35.253            5.9  Low income
# 11                   Burundi         BDI     44.151            1.3  Low income
# 13                     Benin         BEN     36.440            4.9  Low income
# 14              Burkina Faso         BFA     40.551            9.1  Low income
# 29  Central African Republic         CAF     34.076            3.5  Low income

# %%
imp1
# Out:
#              Country Name Country Code  Birth rate  Internet users  \
# 0                   Aruba          ABW      10.244            78.9
# 1             Afghanistan          AFG      35.253             5.9
# 2                  Angola          AGO      45.985            19.1
# 3                 Albania          ALB      12.877            57.2
# 4    United Arab Emirates          ARE      11.044            88.0
# ..                    ...          ...         ...             ...
# 190           Yemen, Rep.          YEM      32.947            20.0
# 191          South Africa          ZAF      20.850            46.5
# 192      Congo, Dem. Rep.          COD      42.394             2.2
# 193                Zambia          ZMB      40.471            15.4
# 194              Zimbabwe          ZWE      35.715            18.5
#
#             Income Group
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ...

# %%
Filter2=imp1.BirthRate>40

# %%
imp1[Filter2]
# Out:
#           CountryName CountryCode  BirthRate  InternetUsers  \
# 2              Angola         AGO     45.985           19.1
# 11            Burundi         BDI     44.151            1.3
# 14       Burkina Faso         BFA     40.551            9.1
# 65        Gambia, The         GMB     42.525           14.0
# 115              Mali         MLI     44.138            3.5
# 127             Niger         NER     49.661            1.7
# 128           Nigeria         NGA     40.045           38.0
# 156           Somalia         SOM     43.891            1.5
# 167              Chad         TCD     45.745            2.3
# 178            Uganda         UGA     43.474           16.2
# 192  Congo, Dem. Rep.         COD     42.394            2.2
# 193            Zambia         ZMB     40.471           15.4
#
#              IncomeGroup
# 2    Upper middle income
# 11            Low income
# 14            Low income
# 65            Low income
# 115           Low income
# 127           Low income
# ...

# %%
imp1[imp1.BirthRate<40]
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 0                   Aruba         ABW     10.244           78.9
# 1             Afghanistan         AFG     35.253            5.9
# 3                 Albania         ALB     12.877           57.2
# 4    United Arab Emirates         ARE     11.044           88.0
# 5               Argentina         ARG     17.716           59.9
# ..                    ...         ...        ...            ...
# 188    West Bank and Gaza         PSE     30.394           46.6
# 189                 Samoa         WSM     26.172           15.3
# 190           Yemen, Rep.         YEM     32.947           20.0
# 191          South Africa         ZAF     20.850           46.5
# 194              Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 0            High income
# 1             Low income
# 3    Upper middle income
# 4            High income
# 5            High income
# ..                   ...
# ...

# %%
imp1[(imp1.BirthRate>40) | (imp1.InternetUsers<2)]
# Out:
#           CountryName CountryCode  BirthRate  InternetUsers  \
# 2              Angola         AGO     45.985           19.1
# 11            Burundi         BDI     44.151            1.3
# 14       Burkina Faso         BFA     40.551            9.1
# 52            Eritrea         ERI     34.800            0.9
# 55           Ethiopia         ETH     32.925            1.9
# 64             Guinea         GIN     37.337            1.6
# 65        Gambia, The         GMB     42.525           14.0
# 115              Mali         MLI     44.138            3.5
# 117           Myanmar         MMR     18.119            1.6
# 127             Niger         NER     49.661            1.7
# 128           Nigeria         NGA     40.045           38.0
# 154      Sierra Leone         SLE     36.729            1.7
# 156           Somalia         SOM     43.891            1.5
# 167              Chad         TCD     45.745            2.3
# 172       Timor-Leste         TLS     35.755            1.1
# ...

# %%
imp1[imp1.CountryName=="Malta"]
# Out:
#     CountryName CountryCode  BirthRate  InternetUsers  IncomeGroup
# 116       Malta         MLT        9.5        68.9138  High income

# %%
imp1[imp1.]
# Out:
#   File "<ipython-input-111-e7ae80a364e1>", line 1
#     imp1[imp1.]
#               ^
# SyntaxError: invalid syntax

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize']=8,4
import warnings
warnings.filterwarnings('ignore')

# %%
imp1.head()
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
vis1=sns.distplot(imp1["InternetUsers"],bins=40)

# %%
vis2=sns.boxplot(data=imp1,x='IncomeGroup',y='BirthRate')

# %%
imp1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-709cd1dddecb> in <module>
# ----> 1 imp1
#
# NameError: name 'imp1' is not defined

# %%
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize']=8,4
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
vis1= sns.boxplot(data=imp1,x='IncomeGroup',y='BirthRate')

# %%
vis2=sns.lmplot(data=imp1,x="InternetUsers",y="BirthRate",fit_reg=False,hue='IncomeGroup',size=5,scatter_kws={"s":150})
